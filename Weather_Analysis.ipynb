# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.linear_model import LinearRegression

# %%
dataset=pd.read_csv("/content/drive/MyDrive/austin_weather.csv")

# %%
dataset
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
dataset=dataset.drop(["Events","Date","SeaLevelPressureLowInches"],axis=1)

# %%
dataset=dataset.replace('T',0.00)
dataset=dataset.replace('-',0.00)
dataset
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
# ...

# %%
dataset.to_csv("austin_weather_final.csv")

# %%
data=pd.read_csv("austin_weather_final.csv")

# %%
x=data.drop(["PrecipitationSumInches"],axis=1)
Y=data["PrecipitationSumInches"]

# %%
Y=Y.values.reshape(-1,1)
Y
# Out:
# array([[0.46],
#        [0.  ],
#        [0.  ],
#        ...,
#        [0.  ],
#        [0.  ],
#        [0.  ]])

# %%
clf=LinearRegression()
clf.fit(x,Y)
# Out:
# LinearRegression()

# %%
day_index=600
days=[i for i in range(Y.size)]
days

# %%
plt.scatter(days,Y,color='g')
plt.scatter(days[day_index],Y[day_index],color='r')
plt.title("precipitation Level")
plt.xlabel("Days")
plt.ylabel("precipitation in inches")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.datasets import load_iris
iris=load_iris()

# %%
x=iris.data
y=iris.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
